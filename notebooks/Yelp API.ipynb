# %%
import requests
import json
import pandas as pd

# %%
open_restaurants = pd.read_pickle('./open_restaurants.pkl')
open_restaurants
# Out:
#                                                        name
# business_id
# tstimHoMcYbkSC4eBA1wEg  Maria's Mexican Restaurant & Bakery
# 6fPQJq4f_yiq1NHn0fd11Q                          La Creperie
# k-dDZvTeLysoJvjHI-qr9g                         Feast Buffet
# iwGhazq9eP51PSerTrMrwg                    Mr G's Pub & Grub
# 0G83H_zoum-Q4bWU2olTqQ                Bonjour Bakery & Deli
# k2b3niokS_tosjah_rzCPw                          Metro Pizza
# dusNIzdCaH6EoLl2hRy6cQ               Chipotle Mexican Grill
# hgQOESYp7CF4LnNI90XEiw                          800 Degrees
# F06m2yQSPHIrb1IT7heYeQ                      Rainbow Kitchen
# H2Chxto2e6dHTDJ8-s3-pQ                  Roberto's Taco Shop
# yKpdzrqe_qIbu9dB6bj9Gg                       PGA Tour Grill
# lXCmTGagqHuPgaeN2g2P1Q                         Marcos Pizza
# tk7__jHNlFMsfShjv5CJNQ                    Prince Restaurant
# SAfuIUZMXrOnb3LWyvYjDA              Jun's Korean Restaurant
# ...

# %%
HEADERS = {'Authorization':'Bearer %s' %'t2POjvVZfc64zVMRRDEvhFA_ffRJpB_MJvk0oqiOcJvyBtu_42soOy-m6JQo0JSZyqESd56-bE41ZxXRv8qmSXs01Pb05hCU-UocJXlOLFytEpodpjFWNZWkypgoXnYx'}
URL = 'https://api.yelp.com/v3/businesses/'
print HEADERS
print URL
# Out:
# {'Authorization': 'Bearer t2POjvVZfc64zVMRRDEvhFA_ffRJpB_MJvk0oqiOcJvyBtu_42soOy-m6JQo0JSZyqESd56-bE41ZxXRv8qmSXs01Pb05hCU-UocJXlOLFytEpodpjFWNZWkypgoXnYx'}
# https://api.yelp.com/v3/businesses/

# %%
url = 'https://api.yelp.com/v3/businesses/matches'
params = {'name' : 'Egg Works', 'address1' : '9355 W Flamingo Rd', 'city' : 'Las Vegas', 'state' : 'NV', 'country' : 'US'}
params

request = requests.get(url, params = params, headers = HEADERS)
print request.status_code

response_blob = json.loads(request.text)['businesses']#[0]
#coords = response_blob[u'coordinates']
#latitude, longitude = coords[u'latitude'], coords[u'longitude']
#print latitude, longitude, response_blob['name']
response_blob
# Out:
# 200
# [{u'alias': u'egg-works-las-vegas',
#   u'coordinates': {u'latitude': 36.114517160807,
#    u'longitude': -115.295586365519},
#   u'display_phone': u'(702) 368-3447',
#   u'id': u'4qG3Gh8QyugC1XvoTlmgcQ',
#   u'location': {u'address1': u'9355 W Flamingo Rd',
#    u'address2': u'',
#    u'address3': u'',
#    u'city': u'Las Vegas',
#    u'country': u'US',
#    u'display_address': [u'9355 W Flamingo Rd', u'Las Vegas, NV 89147'],
#    u'state': u'NV',
#    u'zip_code': u'89147'},
#   u'name': u'Egg Works',
#   u'phone': u'+17023683447'}]

# %%
request = requests.get('https://api.yelp.com/v3/businesses/{business_id}/reviews'.format(business_id=u'vWcDq3HDcN8PsoErage4jA'), headers= HEADERS)
print json.loads(request.text)
# Out:
# {u'reviews': [{u'rating': 5, u'url': u'https://www.yelp.com/biz/jack-in-the-box-las-vegas-53?adjust_creative=-FCg0VAa4lr2x-6zbuQ4mA&hrid=Pa_fNBATzeC0SbiyBgDdbQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=-FCg0VAa4lr2x-6zbuQ4mA', u'text': u'Always received what I ordered.  I mishaps yet. I leave a few blocks down, so this is great!', u'time_created': u'2020-01-22 23:35:12', u'user': {u'image_url': u'https://s3-media4.fl.yelpcdn.com/photo/GA03T_EaRHksgbLtVPpx2g/o.jpg', u'id': u'xpj3tWkgPhF0bEPvDVuBtw', u'profile_url': u'https://www.yelp.com/user_details?userid=xpj3tWkgPhF0bEPvDVuBtw', u'name': u'Jeffrey S.'}, u'id': u'Pa_fNBATzeC0SbiyBgDdbQ'}, {u'rating': 1, u'url': u'https://www.yelp.com/biz/jack-in-the-box-las-vegas-53?adjust_creative=-FCg0VAa4lr2x-6zbuQ4mA&hrid=IhEiNjNzPIPoDOnXTZnfVg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=-FCg0VAa4lr2x-6zbuQ4mA', u'text': u'Normally speaking I rarely put a negative review. I live across from
# ...

# %%
#name = open_restaurants.iloc[0]['name']
#address = open_restaurants.iloc[0]['address']
#print name
#print address
#open_restaurants.index

# %%
url = 'https://api.yelp.com/v3/businesses/4qG3Gh8QyugC1XvoTlmgcQ'

request = requests.get(url, headers=HEADERS)
print request.status_code

#print json.loads(request.text)
for category in json.loads(request.text)['categories']:
    print category['alias'], category['title']
# Out:
# 200
# tradamerican American (Traditional)
# breakfast_brunch Breakfast & Brunch
# burgers Burgers

# %%
url = 'https://api.yelp.com/v3/businesses/search'
params = {'latitude' : '36.114517160807', 'longitude' : '-115.295586365519', \
          'categories': 'tradamerican,breakfast_brunch,burgers'}

request = requests.get(url, params=params, headers=HEADERS)
print request.status_code, '\n'

for blob in json.loads(request.text)['businesses']:
    if blob['name'] != 'Egg Works':
        num_matching_cats = 0
        for category in blob['categories']:
            if category['alias'] == 'tradamerican':
                num_matching_cats += 1
            elif category['alias'] == 'breakfast_brunch':
                num_matching_cats += 1
            elif category['alias'] == 'burgers':
                num_matching_cats += 1
                
        if num_matching_cats != 0:
            print blob['name'], blob['categories'], num_matching_cats
# Out:
# 200
#
# Wing King [{u'alias': u'chicken_wings', u'title': u'Chicken Wings'}, {u'alias': u'burgers', u'title': u'Burgers'}, {u'alias': u'pizza', u'title': u'Pizza'}] 1
# Cafe Breizh [{u'alias': u'bakeries', u'title': u'Bakeries'}, {u'alias': u'breakfast_brunch', u'title': u'Breakfast & Brunch'}, {u'alias': u'french', u'title': u'French'}] 1
# Rise & Shine : A Steak & Egg Place [{u'alias': u'breakfast_brunch', u'title': u'Breakfast & Brunch'}, {u'alias': u'sandwiches', u'title': u'Sandwiches'}, {u'alias': u'tradamerican', u'title': u'American (Traditional)'}] 2
# Mimosas Gourmet [{u'alias': u'breakfast_brunch', u'title': u'Breakfast & Brunch'}, {u'alias': u'salad', u'title': u'Salad'}, {u'alias': u'sandwiches', u'title': u'Sandwiches'}] 1
# Toasted Gastrobrunch [{u'alias': u'breakfast_brunch', u'title': u'Breakfast & Brunch'}] 1
# ...

# %%
#json.loads(request2.text)

# %%
def do_yelp_request(restaurants_df):
    is_open_list = []
    not_found_ids_list = []
    
    for index, row in restaurants_df.iterrows():
        name = row['name']
        
        url = URL + index
        
        request = requests.get(url, headers = HEADERS)
    
        status_code = request.status_code
        
        if status_code != 200:
            print "Error status code (%d) for name: %s"%(status_code, name)
        else:
            response = json.loads(request.text)
            if name == response['name']:
                is_open = not response['is_closed']
                try:
                    price = response['price']
                except:
                    print "No price for %s. Setting it to 0"%(name)
                    price = '0'
                try:
                    rating = response['rating']
                except:
                    print "No rating for %s. Setting it to 0.0"%(name)
                    rating = '0.0'
                try:
                    review_count = response['review_count']
                except:
                    print "No review count for %s. Setting it to 0"%(name)
                    review_count = '0'
                try:
                    is_claimed = response['is_claimed']
                except:
                    print "No is_claimed for %s. Setting it to False"%(name)
                    is_claimed = False

                try:
                    has_photos = len(response['photos']) > 0
                except:
                    print "No photos. Setting it to 0"%s(name)
                    has_photos = False

                coords = response['coordinates']
                latitude = coords['latitude']
                longitude = coords['longitude']

                #print "Found restaurant (%s) with Yelp API. Is open: %d"%(name, is_open)
                is_open_list.append( (index, name, is_open, price, rating, review_count, \
                                      latitude, longitude, is_claimed, has_photos) )       
    return is_open_list

# %%
# Be careful running this cell, check to see if you have enough API requests for the day
is_open_list = do_yelp_request(open_restaurants)
#is_open_list
# Out:
# No price for Carnitas y Tortas Ahogadas Guadalajara 2. Setting it to 0
# No price for Cariba Charlie's. Setting it to 0
# No price for Big League Dreams Sport Park. Setting it to 0
# No price for El Buen Gusto. Setting it to 0
# No price for Fountains of Bellagio. Setting it to 0
# No price for Sin City Soul Deli Caribbean BBQ. Setting it to 0
# No price for Vegas All Nite. Setting it to 0
# No price for New Granada. Setting it to 0
# No price for Sin Citys Taco China. Setting it to 0
# No price for Forte Family Practice. Setting it to 0
# No price for Pinball Hall Of Fame. Setting it to 0
# No price for Margaritaville Casino. Setting it to 0
# No price for Parsley Modern Mediterranean. Setting it to 0
# No price for Del Taco. Setting it to 0
# No price for AAA Bar & Restaurant Supply. Setting it to 0
# No price for Clark County Detention Center. Setting it to 0
# No price for Aquatic Treasures. Setting it to 0
# No price for Pho Thanh Long. Setting it to 0
# ...

# %%
yelp_api_data_df = pd.DataFrame(is_open_list, columns=['business_id','name','is_still_open','price','rating','review_count','latitude','longitude','is_claimed','has_photos']).set_index('business_id')
yelp_api_data_df.to_pickle('./open_restaurants_yelp_api_data_df.pkl')
yelp_api_data_df
# Out:
#                                                        name  is_still_open  \
# business_id
# tstimHoMcYbkSC4eBA1wEg  Maria's Mexican Restaurant & Bakery           True
# 6fPQJq4f_yiq1NHn0fd11Q                          La Creperie           True
# k-dDZvTeLysoJvjHI-qr9g                         Feast Buffet           True
# iwGhazq9eP51PSerTrMrwg                    Mr G's Pub & Grub           True
# 0G83H_zoum-Q4bWU2olTqQ                Bonjour Bakery & Deli          False
# k2b3niokS_tosjah_rzCPw                          Metro Pizza           True
# dusNIzdCaH6EoLl2hRy6cQ               Chipotle Mexican Grill           True
# hgQOESYp7CF4LnNI90XEiw                          800 Degrees          False
# F06m2yQSPHIrb1IT7heYeQ                      Rainbow Kitchen           True
# H2Chxto2e6dHTDJ8-s3-pQ                  Roberto's Taco Shop           True
# yKpdzrqe_qIbu9dB6bj9Gg                       PGA Tour Grill           True
# ...

# %%
not_found_restaurants_yelp_api_df = open_restaurants[~open_restaurants.index.isin(yelp_api_data_df.index)]
not_found_restaurants_yelp_api_df.to_pickle('./not_found_restaurants_yelp_api_df.pkl')
not_found_restaurants_yelp_api_df
# figure out what happened to these 307 restaurants
# Out:
#                                                       name
# business_id
# MXpCVzm1V5OH05KO6n7ntA              The Corndog Company LV
# aBCqrJwXAHnTgO2e_l0v8w                           Carl's Jr
# gPZj-XXVwFHgd8zjJPzVCw                              Subway
# G9-OvE0PBQtDZmnGEB3HEQ                       Einstein Bros
# TRlBYLf4CxFBaGE-9FLOtA        Greenwich Village Coffee Co.
# Ia1JlEo7UUyZtmqRe1K1Pw             Makers & Finders Coffee
# TIUd6XX7-hF6EPF2NowMsA                              Subway
# FkdG2Qsh0V2UmrEOn_ImDA   Taqueria El Buen Pastor Foodtruck
# YyxB3K1ORzc7ChMKgyxm9Q                              Subway
# 2hrj6ISpLJmvRen3AZkBWw                              Subway
# ivXSATui5znHvRuVExj3vw                              Subway
# AyKOSCyaPb7x8a9gqZ0z2A                              Subway
# IkmL3syVMj8zZxpL-7SYsw                              Subway
# wFU96ah70juScw822O4Zpw                              Subway
# WlqxMI84U-Cku3Qs-tJUJQ                              Subway
# ...
